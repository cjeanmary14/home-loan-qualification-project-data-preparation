# %%
import pandas as pd

# %%
df = pd.read_csv('loan_sanction_test.csv')
df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df2 = df[df['LoanAmount'].notnull() ]
df2
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df2.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents            9
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %%
df3 = df2[df2['Self_Employed'].notnull() ]
df3
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df3.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents            9
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      6
# Credit_History       28
# Property_Area         0
# dtype: int64

# %%
df4 = df3[df3['Loan_Amount_Term'].notnull() ]
df4
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df4.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents            9
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       27
# Property_Area         0
# dtype: int64

# %%
group = df4.groupby(['Credit_History'])['Credit_History'].count()
group
# Out:
# Credit_History
# 0.0     48
# 1.0    258
# Name: Credit_History, dtype: int64

# %%
credit_null = df4[df4['Credit_History'].isnull( )]
credit_null
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 3    LP001035    Male     Yes          2      Graduate            No
# 12   LP001083    Male      No         3+      Graduate            No
# 26   LP001163    Male     Yes          2      Graduate            No
# 28   LP001174    Male     Yes          0      Graduate            No
# 90   LP001475    Male     Yes          0      Graduate           Yes
# 99   LP001527    Male     Yes         3+      Graduate            No
# 104  LP001558    Male      No          0      Graduate            No
# 115  LP001601    Male      No         3+      Graduate            No
# 139  LP001771  Female      No         3+      Graduate            No
# 143  LP001791    Male     Yes          0      Graduate           Yes
# 164  LP001921    Male      No          1      Graduate            No
# 177  LP002009  Female      No          0      Graduate            No
# 179  LP002017    Male     Yes         3+      Graduate            No
# ...

# %%
df4.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       333.000000         333.000000  333.000000        333.000000
# mean       4725.120120        1541.294294  135.588589        342.510511
# std        5002.578546        2383.037439   61.761313         64.597111
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2875.000000           0.000000  100.000000        360.000000
# 50%        3772.000000        1000.000000  125.000000        360.000000
# 75%        5000.000000        2382.000000  153.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      306.000000
# mean         0.843137
# std          0.364267
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df5 = df4[df4['Credit_History'].notnull()]
df5
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df5.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents            7
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %%
dependants = df5.groupby(['Dependents'])['Dependents'].count()
dependants
# Out:
# Dependents
# 0     174
# 1      44
# 2      50
# 3+     31
# Name: Dependents, dtype: int64

# %%
df6  = df5[df5['Dependents'].notnull()]
df6
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df6.isnull().sum()
# Out:
# Loan_ID               0
# Gender               10
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# dtype: int64

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            299 non-null    object
#  1   Gender             289 non-null    object
#  2   Married            299 non-null    object
#  3   Dependents         299 non-null    object
#  4   Education          299 non-null    object
#  5   Self_Employed      299 non-null    object
#  6   ApplicantIncome    299 non-null    int64
#  7   CoapplicantIncome  299 non-null    int64
#  8   LoanAmount         299 non-null    float64
#  9   Loan_Amount_Term   299 non-null    float64
#  10  Credit_History     299 non-null    float64
#  11  Property_Area      299 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 30.4+ KB

# %%
df6.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       299.000000         299.000000  299.000000        299.000000
# mean       4676.478261        1526.909699  136.277592        342.648829
# std        4933.816391        2352.551815   59.013079         65.298235
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  102.000000        360.000000
# 50%        3829.000000         879.000000  125.000000        360.000000
# 75%        5000.000000        2400.000000  156.500000        360.000000
# max       72529.000000       24000.000000  460.000000        480.000000
#
#        Credit_History
# count      299.000000
# mean         0.839465
# std          0.367717
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
# Replacing null values with 'N/A'

df7 = df6.fillna({'Gender': 'N/A'})
df7
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df7.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
df7
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df7['Credit_History'] = df7['Credit_History'].astype(str)

# %%
df7['Credit_History'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 299 entries, 0 to 366
# Series name: Credit_History
# Non-Null Count  Dtype
# --------------  -----
# 299 non-null    object
# dtypes: object(1)
# memory usage: 4.7+ KB

# %%
df7.loc[df7['Credit_History'] == '0.0', 'Credit_History'] = 'No'

# %%
df7.loc[df7['Credit_History'] == '1.0', 'Credit_History'] = 'Yes'

# %%
Cred = df7.groupby(['Credit_History'])['Credit_History'].count()
Cred
# Out:
# Credit_History
# No      48
# Yes    251
# Name: Credit_History, dtype: int64

# %%
df7
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# 5    LP001054   Male     Yes          0  Not Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            299 non-null    object
#  1   Gender             299 non-null    object
#  2   Married            299 non-null    object
#  3   Dependents         299 non-null    object
#  4   Education          299 non-null    object
#  5   Self_Employed      299 non-null    object
#  6   ApplicantIncome    299 non-null    int64
#  7   CoapplicantIncome  299 non-null    int64
#  8   LoanAmount         299 non-null    float64
#  9   Loan_Amount_Term   299 non-null    float64
#  10  Credit_History     299 non-null    object
#  11  Property_Area      299 non-null    object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 30.4+ KB

# %%
df7['Credit_History'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 299 entries, 0 to 366
# Series name: Credit_History
# Non-Null Count  Dtype
# --------------  -----
# 299 non-null    float64
# dtypes: float64(1)
# memory usage: 4.7 KB

# %%
gender = df7.groupby(['Gender'])['Gender'].count()
gender
# Out:
# Gender
# Female     59
# Male      230
# N/A        10
# Name: Gender, dtype: int64

# %%
df4
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 333 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            333 non-null    object
#  1   Gender             322 non-null    object
#  2   Married            333 non-null    object
#  3   Dependents         324 non-null    object
#  4   Education          333 non-null    object
#  5   Self_Employed      333 non-null    object
#  6   ApplicantIncome    333 non-null    int64
#  7   CoapplicantIncome  333 non-null    int64
#  8   LoanAmount         333 non-null    float64
#  9   Loan_Amount_Term   333 non-null    float64
#  10  Credit_History     306 non-null    float64
#  11  Property_Area      333 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 33.8+ KB

# %%
df4['Gender'].isnull().sum()
# Out:
# 11

# %%
df4.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents            9
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History       27
# Property_Area         0
# dtype: int64

# %%
df4.to_csv('C:\\Users\\cjean\\\OneDrive\\Documents\\Home_Loan_Data_Project\\New_Home_Loan_Data.csv')

# %%
df_2 = pd.read_csv('loan_sanction_train.csv')
df_2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df_2.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df_2.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df2_2 = df_2[df_2['LoanAmount'].notnull()]
df2_2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df2_2.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       592.000000         592.000000  592.000000        578.000000
# mean       5404.304054        1642.633311  146.412162        342.145329
# std        6164.073003        2967.717486   85.587325         65.442101
# min         150.000000           0.000000    9.000000         12.000000
# 25%        2887.250000           0.000000  100.000000        360.000000
# 50%        3806.000000        1221.000000  128.000000        360.000000
# 75%        5754.500000        2312.000000  168.000000        360.000000
# max       81000.000000       41667.000000  700.000000        480.000000
#
#        Credit_History
# count      543.000000
# mean         0.843462
# std          0.363699
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df2_2.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               2
# Dependents           13
# Education             0
# Self_Employed        31
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History       49
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df3_2 = df2_2[df2_2['Credit_History'].notnull()]
df3_2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df3_2.isnull().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               2
# Dependents           13
# Education             0
# Self_Employed        26
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     14
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df4_2 = df3_2[df3_2['Loan_Amount_Term'].notnull()]
df4_2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df4_2.isnull().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               2
# Dependents           12
# Education             0
# Self_Employed        25
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df5_2 = df4_2[df4_2['Self_Employed'].notnull()]
df5_2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df5_2.isnull().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               2
# Dependents           12
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df6_2 = df5_2[df5_2['Dependents'].notnull()]
df6_2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df6_2.isnull().sum()
# Out:
# Loan_ID               0
# Gender               12
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df7_2 = df6_2.fillna({'Gender': 'N/A'})
df7_2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df7_2.groupby(['Gender'])['Gender'].count()
# Out:
# Gender
# Female     86
# Male      394
# N/A        12
# Name: Gender, dtype: int64

# %%
df7_2['Credit_History'] = df7_2['Credit_History'].astype(str)
df7_2.loc[df7_2['Credit_History'] == '0.0', 'Credit_History'] = 'No'
df7_2.loc[df7_2['Credit_History'] == '1.0', 'Credit_History'] = 'Yes'

# %%
df7_2
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df7_2.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# count       492.000000         492.000000  492.000000        492.000000
# mean       5502.203252        1572.959187  146.390244        342.000000
# std        6069.324665        2597.096132   84.352947         64.902747
# min         150.000000           0.000000    9.000000         36.000000
# 25%        2898.750000           0.000000  100.000000        360.000000
# 50%        3859.000000        1084.500000  128.000000        360.000000
# 75%        5936.500000        2250.000000  170.500000        360.000000
# max       81000.000000       33837.000000  700.000000        480.000000

# %%
df7_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 492 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            492 non-null    object
#  1   Gender             492 non-null    object
#  2   Married            492 non-null    object
#  3   Dependents         492 non-null    object
#  4   Education          492 non-null    object
#  5   Self_Employed      492 non-null    object
#  6   ApplicantIncome    492 non-null    int64
#  7   CoapplicantIncome  492 non-null    float64
#  8   LoanAmount         492 non-null    float64
#  9   Loan_Amount_Term   492 non-null    float64
#  10  Credit_History     492 non-null    object
#  11  Property_Area      492 non-null    object
#  12  Loan_Status        492 non-null    object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 53.8+ KB

# %%
df7_2['CoapplicantIncome'] = df7_2['CoapplicantIncome'].astype(int)

# %%
df7_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 492 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            492 non-null    object
#  1   Gender             492 non-null    object
#  2   Married            492 non-null    object
#  3   Dependents         492 non-null    object
#  4   Education          492 non-null    object
#  5   Self_Employed      492 non-null    object
#  6   ApplicantIncome    492 non-null    int64
#  7   CoapplicantIncome  492 non-null    int32
#  8   LoanAmount         492 non-null    float64
#  9   Loan_Amount_Term   492 non-null    float64
#  10  Credit_History     492 non-null    object
#  11  Property_Area      492 non-null    object
#  12  Loan_Status        492 non-null    object
# dtypes: float64(2), int32(1), int64(1), object(9)
# memory usage: 51.9+ KB

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            299 non-null    object
#  1   Gender             299 non-null    object
#  2   Married            299 non-null    object
#  3   Dependents         299 non-null    object
#  4   Education          299 non-null    object
#  5   Self_Employed      299 non-null    object
#  6   ApplicantIncome    299 non-null    int64
#  7   CoapplicantIncome  299 non-null    int64
#  8   LoanAmount         299 non-null    float64
#  9   Loan_Amount_Term   299 non-null    float64
#  10  Credit_History     299 non-null    object
#  11  Property_Area      299 non-null    object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 30.4+ KB

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 299 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            299 non-null    object
#  1   Gender             299 non-null    object
#  2   Married            299 non-null    object
#  3   Dependents         299 non-null    object
#  4   Education          299 non-null    object
#  5   Self_Employed      299 non-null    object
#  6   ApplicantIncome    299 non-null    int64
#  7   CoapplicantIncome  299 non-null    int64
#  8   LoanAmount         299 non-null    float64
#  9   Loan_Amount_Term   299 non-null    float64
#  10  Credit_History     299 non-null    object
#  11  Property_Area      299 non-null    object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 30.4+ KB

# %%
df7_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 492 entries, 1 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            492 non-null    object
#  1   Gender             492 non-null    object
#  2   Married            492 non-null    object
#  3   Dependents         492 non-null    object
#  4   Education          492 non-null    object
#  5   Self_Employed      492 non-null    object
#  6   ApplicantIncome    492 non-null    int64
#  7   CoapplicantIncome  492 non-null    int32
#  8   LoanAmount         492 non-null    float64
#  9   Loan_Amount_Term   492 non-null    float64
#  10  Credit_History     492 non-null    object
#  11  Property_Area      492 non-null    object
#  12  Loan_Status        492 non-null    object
# dtypes: float64(2), int32(1), int64(1), object(9)
# memory usage: 51.9+ KB

# %%
# use df7_2 and df7

merge = pd.concat([df7_2, df7])
merge
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 1    LP001003   Male     Yes          1      Graduate            No
# 2    LP001005   Male     Yes          0      Graduate           Yes
# 3    LP001006   Male     Yes          0  Not Graduate            No
# 4    LP001008   Male      No          0      Graduate            No
# 5    LP001011   Male     Yes          2      Graduate           Yes
# ..        ...    ...     ...        ...           ...           ...
# 361  LP002969   Male     Yes          1      Graduate            No
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 1               4583               1508       128.0             360.0
# ...

# %%
merge.to_csv('C:\\Users\\cjean\\OneDrive\\Documents\\Home_Loan_Data_Project\\Home_Loan.csv')
